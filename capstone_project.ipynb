# %% [markdown]
# # Introduction
# This notebook will be mainly used for the capstone project of the **Applied Data Science** course from [Coursera](https://www.coursera.org).

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
